# %% [markdown]
# # Exploratory Data Analysis Exercise
# * For this part we will be using the `data/cars.csv` dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %matplotlib inline 
import scipy.stats as stats

# %% [markdown]
# # Load in the data
# * Use the file in the data folder called 'cars.csv'
# * Save it as a varible named 'df'
# * Display the first 5 rows of our dataframe

# %%
# Load data
df = pd.read_csv('data/cars.csv')
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 0      Compact         Coupe           26        19        3916  46135
# 1      Compact   Convertible           28        19        3916  40650
# 2      Compact         Coupe           28        20        3916  36350
# 3      Compact         Coupe           28        18        3916  29450
# 4      Compact   Convertible           28        18        3916  34500

# %% [markdown]
# # Data clean up part 1.
#
# 1. Print the number of duplicate rows we have in our dataframe.
#
# 2. Modify our df to have all duplicate rows removed.
#
# 3. Do a sanity check to make sure all duplicates have been removed by printing the total number of duplicate rows again.

# %%
# 1. Print the number of duplicate rows we have in our dataframe.
print(df.duplicate().sum())
# Out:
# 0

# %%
#  2. Modify our df to have all duplicate rows removed. 

print(df.shape, ' before dropping duplicates')

df = df.drop_duplicates()

print(df.shape, ' after dropping duplicates')
# Out:
# (11914, 15)  before dropping duplicates
# (11194, 15)  after dropping duplicates

# %%
# 3. Do a sanity check to make sure all duplicates have been removed by printing the total number of duplicate rows again.

# %% [markdown]
# # Data clean up part 2.
# * Which column has the most null values and how many null values does it have?
# * Print how long our dataframe is.
# * Remove any row that has a null value in it.
# * Do a sanity check and pring how long our dataframe is now that we have removed our null values.

# %%
# * Which column has the most null values and how many null values does it have?

df.isnull().sum()
# Out:
# Make                  0
# Model                 0
# Year                  0
# Engine Fuel Type      3
# Engine HP            69
# Engine Cylinders     30
# Transmission Type     0
# Driven_Wheels         0
# Number of Doors       6
# Vehicle Size          0
# Vehicle Style         0
# highway MPG           0
# city mpg              0
# Popularity            0
# MSRP                  0
# dtype: int64

# %%
# * Print how long our dataframe is.

num_rows = df.shape[0]  # gives number of row count

print(df.shape,num_rows)
# Out:
# (11194, 15) 11194

# %%
# * Remove any row that has a null value in it. 
df = df.dropna()

# %%
# * Do a sanity check and pring how long our dataframe is now that we have removed our null values.
print(df.shape)
# Out:
# (11092, 15)

# %% [markdown]
# ### Make a bar chart that displays how many times each brand of car appears in this data.
# _Brand of car is the `Make` of the car._
# * You can achieve this by using value_counts or by a groupby.  Either is fine with me.

# %%
# Make a bar chart that displays how many times each brand of car appears in this data. 


df.count()
n = len(pd.unique(df['Make']))
n
# Out:
# 47

# %%
df["Make"].value_counts().plot(kind='bar',figsize = (13, 8))

# %% [markdown]
# # Make the cart more legible, by making it a horizontal bar chart and changing the figure size.  And also sort the values so the bar chart displays from lowest to highest.

# %%
# Make the cart more legible, by making it a horizontal bar chart, sorting the values, and changing the figure size.
df["Make"].value_counts().plot(kind='barh',figsize=(13,8))

# %% [markdown]
# ### Make a timeline line chart in which the x-axis is the year, and the y-axis is the average MSRP.
# * What's noticeable about it and what do you think the error is...

# %%
year_msr = df.groupby('Year')['MSRP']
year_means = year_msr.mean()# mean of msr by year
#year_means = year_means.reset_index()
year_means.plot(kind = 'line', x = 'Year', y = 'MSRP', figsize = (13,8))

# %%
year_means.head()
# Out:
#    Year         MSRP
# 0  1990  2032.272727
# 1  1991  2120.196078
# 2  1992  2108.346457
# 3  1993  2211.496855
# 4  1994  2349.328125

# %% [markdown]
# # It seems as though in the years before (and includig) 2000, they were counting in tens.
# Make a new column that is called `adjusted_price`, that contains all prices, however, for every year before 2000 make it 10x the original MSRP.
#    * Hint; you might need to use our old friend `np.where`

# %%
# Make a column where is 10 when year is less than 2000, else 1.
condition = df['Year'] <= 2000
df['adjusted_price'] = np.where(condition,df['MSRP']*10,df['MSRP'])
year_condition = df['Year'] < 2000
df[year_condition]



# Multiply the MSRP by the price adjuster.
# Out:
#                 Make      Model  Year          Engine Fuel Type  Engine HP  \
# 17              Audi        100  1992          regular unleaded      172.0
# 19              Audi        100  1992          regular unleaded      172.0
# 21              Audi        100  1992          regular unleaded      172.0
# 22              Audi        100  1993          regular unleaded      172.0
# 23              Audi        100  1993          regular unleaded      172.0
# 26              Audi        100  1993          regular unleaded      172.0
# 27              Audi        100  1994          regular unleaded      172.0
# 28              Audi        100  1994          regular unleaded      172.0
# 29              Audi        100  1994          regular unleaded      172.0
# 30              Audi        100  1994          regular unleaded      172.0
# 31              Audi        100  1994          regular unleaded      172.0
# 35     Mercedes-Benz  190-Class  1991          regular unleaded      130.0
# 36     Mercedes-Benz  190-Class  1991          regular unleaded      158.0
# 37     Mercedes-Benz  190-Class  1992          regular unleaded      158.0
# 38     Mercedes-Benz  190-Class  1992          regular unleaded      130.0
# 39     Mercedes-Benz  190-Class  1993          regular unleaded      130.0
# 40     Mercedes-Benz  190-Class  1993          regular unleaded      158.0
# 58              Audi        200  1990          regular unleaded      162.0
# 59              Audi        200  1990          regular unleaded      162.0
# 60              Audi        200  1990          regular unleaded      162.0
# 61              Audi        200  1991          regular unleaded      217.0
# 62              Audi        200  1991          regular unleaded      217.0
# 63              Audi        200  1991          regular unleaded      162.0
# 87            Nissan      200SX  1996          regular unleaded      115.0
# 89            Nissan      200SX  1996          regular unleaded      140.0
# 90            Nissan      200SX  1997          regular unleaded      140.0
# 91            Nissan      200SX  1997          regular unleaded      115.0
# 93            Nissan      200SX  1998          regular unleaded      115.0
# 95            Nissan      200SX  1998          regular unleaded      140.0
# 96            Nissan      240SX  1996          regular unleaded      155.0
# ...              ...        ...   ...                       ...        ...
# 11185     Volkswagen    Vanagon  1990          regular unleaded       90.0
# 11189     Volkswagen    Vanagon  1991          regular unleaded       90.0
# 11193            GMC    Vandura  1994          regular unleaded      200.0
# 11194            GMC    Vandura  1994          regular unleaded      165.0
# 11195            GMC    Vandura  1994          regular unleaded      165.0
# 11197            GMC    Vandura  1994          regular unleaded      200.0
# 11199            GMC    Vandura  1995          regular unleaded      165.0
# 11200            GMC    Vandura  1995          regular unleaded      165.0
# 11201            GMC    Vandura  1995          regular unleaded      165.0
# 11204         Nissan        Van  1990          regular unleaded      106.0
# 11205         Nissan        Van  1990          regular unleaded      106.0
# 11214     Mitsubishi   Vanwagon  1990          regular unleaded      107.0
# 11215     Mitsubishi   Vanwagon  1990          regular unleaded      107.0
# 11374          Acura      Vigor  1992          regular unleaded      176.0
# 11376          Acura      Vigor  1993          regular unleaded      176.0
# 11378          Acura      Vigor  1994          regular unleaded      176.0
# 11419       Plymouth    Voyager  1998          regular unleaded      150.0
# 11420       Plymouth    Voyager  1998          regular unleaded      150.0
# 11422       Plymouth    Voyager  1999  flex-fuel (unleaded/E85)      158.0
# 11423       Plymouth    Voyager  1999  flex-fuel (unleaded/E85)      158.0
# 11424       Plymouth    Voyager  1999          regular unleaded      150.0
# 11476         Suzuki       X-90  1996          regular unleaded       95.0
# 11477         Suzuki       X-90  1996          regular unleaded       95.0
# 11478         Suzuki       X-90  1997          regular unleaded       95.0
# 11479         Suzuki       X-90  1997          regular unleaded       95.0
# 11480         Suzuki       X-90  1998          regular unleaded       95.0
# 11482         Suzuki       X-90  1998          regular unleaded       95.0
# 11792         Subaru         XT  1991          regular unleaded       97.0
# 11793         Subaru         XT  1991          regular unleaded      145.0
# 11794         Subaru         XT  1991          regular unleaded      145.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 17                  6.0            MANUAL  front wheel drive              4.0
# 19                  6.0         AUTOMATIC    all wheel drive              4.0
# 21                  6.0            MANUAL    all wheel drive              4.0
# 22                  6.0            MANUAL  front wheel drive              4.0
# 23                  6.0         AUTOMATIC    all wheel drive              4.0
# 26                  6.0            MANUAL    all wheel drive              4.0
# 27                  6.0         AUTOMATIC  front wheel drive              4.0
# 28                  6.0            MANUAL    all wheel drive              4.0
# 29                  6.0            MANUAL  front wheel drive              4.0
# 30                  6.0         AUTOMATIC  front wheel drive              4.0
# 31                  6.0         AUTOMATIC    all wheel drive              4.0
# 35                  4.0            MANUAL   rear wheel drive              4.0
# 36                  6.0            MANUAL   rear wheel drive              4.0
# 37                  6.0            MANUAL   rear wheel drive              4.0
# 38                  4.0            MANUAL   rear wheel drive              4.0
# 39                  4.0            MANUAL   rear wheel drive              4.0
# 40                  6.0            MANUAL   rear wheel drive              4.0
# 58                  5.0         AUTOMATIC  front wheel drive              4.0
# 59                  5.0            MANUAL    all wheel drive              4.0
# 60                  5.0            MANUAL    all wheel drive              4.0
# 61                  5.0            MANUAL    all wheel drive              4.0
# 62                  5.0            MANUAL    all wheel drive              4.0
# 63                  5.0         AUTOMATIC  front wheel drive              4.0
# 87                  4.0            MANUAL  front wheel drive              2.0
# 89                  4.0            MANUAL  front wheel drive              2.0
# 90                  4.0            MANUAL  front wheel drive              2.0
# 91                  4.0            MANUAL  front wheel drive              2.0
# 93                  4.0            MANUAL  front wheel drive              2.0
# 95                  4.0            MANUAL  front wheel drive              2.0
# 96                  4.0            MANUAL   rear wheel drive              2.0
# ...                 ...               ...                ...              ...
# 11185               4.0            MANUAL   rear wheel drive              3.0
# 11189               4.0            MANUAL   rear wheel drive              3.0
# 11193               6.0         AUTOMATIC   rear wheel drive              3.0
# 11194               6.0         AUTOMATIC   rear wheel drive              3.0
# 11195               6.0         AUTOMATIC   rear wheel drive              3.0
# 11197               8.0         AUTOMATIC   rear wheel drive              3.0
# 11199               6.0         AUTOMATIC   rear wheel drive              3.0
# 11200               6.0         AUTOMATIC   rear wheel drive              3.0
# 11201               6.0         AUTOMATIC   rear wheel drive              3.0
# 11204               4.0         AUTOMATIC   rear wheel drive              3.0
# 11205               4.0            MANUAL   rear wheel drive              3.0
# 11214               4.0         AUTOMATIC   rear wheel drive              3.0
# 11215               4.0         AUTOMATIC   rear wheel drive              3.0
# 11374               5.0            MANUAL  front wheel drive              4.0
# 11376               5.0            MANUAL  front wheel drive              4.0
# 11378               5.0            MANUAL  front wheel drive              4.0
# 11419               4.0         AUTOMATIC  front wheel drive              3.0
# 11420               6.0         AUTOMATIC  front wheel drive              4.0
# 11422               6.0         AUTOMATIC  front wheel drive              4.0
# 11423               6.0         AUTOMATIC  front wheel drive              4.0
# 11424               4.0         AUTOMATIC  front wheel drive              3.0
# 11476               4.0            MANUAL   four wheel drive              2.0
# 11477               4.0            MANUAL   rear wheel drive              2.0
# 11478               4.0            MANUAL   four wheel drive              2.0
# 11479               4.0            MANUAL   rear wheel drive              2.0
# 11480               4.0            MANUAL   four wheel drive              2.0
# 11482               4.0            MANUAL   rear wheel drive              2.0
# 11792               4.0            MANUAL  front wheel drive              2.0
# 11793               6.0         AUTOMATIC  front wheel drive              2.0
# 11794               6.0            MANUAL    all wheel drive              2.0
#
#       Vehicle Size      Vehicle Style  highway MPG  city mpg  Popularity  \
# 17         Midsize              Sedan           24        17        3105
# 19         Midsize              Wagon           20        16        3105
# 21         Midsize              Sedan           21        16        3105
# 22         Midsize              Sedan           24        17        3105
# 23         Midsize              Wagon           20        16        3105
# 26         Midsize              Sedan           21        16        3105
# 27         Midsize              Wagon           21        16        3105
# 28         Midsize              Sedan           22        16        3105
# 29         Midsize              Sedan           22        17        3105
# 30         Midsize              Sedan           22        16        3105
# 31         Midsize              Wagon           21        16        3105
# 35         Compact              Sedan           26        18         617
# 36         Compact              Sedan           25        17         617
# 37         Compact              Sedan           25        17         617
# 38         Compact              Sedan           26        18         617
# 39         Compact              Sedan           26        18         617
# 40         Compact              Sedan           25        17         617
# 58         Midsize              Sedan           20        16        3105
# 59         Midsize              Wagon           22        15        3105
# 60         Midsize              Sedan           23        15        3105
# 61         Midsize              Sedan           22        16        3105
# 62         Midsize              Wagon           22        16        3105
# 63         Midsize              Sedan           20        16        3105
# 87         Compact              Coupe           36        26        2009
# 89         Compact              Coupe           29        21        2009
# 90         Compact              Coupe           29        21        2009
# 91         Compact              Coupe           35        25        2009
# 93         Compact              Coupe           35        25        2009
# 95         Compact              Coupe           28        20        2009
# 96         Compact              Coupe           26        19        2009
# ...            ...                ...          ...       ...         ...
# 11185        Large  Passenger Minivan           18        16         873
# 11189        Large  Passenger Minivan           18        16         873
# 11193      Midsize          Cargo Van           20        15         549
# 11194      Midsize          Cargo Van           20        15         549
# 11195      Compact          Cargo Van           20        15         549
# 11197        Large          Cargo Van           16        12         549
# 11199      Midsize          Cargo Van           20        15         549
# 11200      Midsize          Cargo Van           15        13         549
# 11201      Compact          Cargo Van           20        15         549
# 11204      Compact  Passenger Minivan           19        15        2009
# 11205      Compact  Passenger Minivan           20        16        2009
# 11214      Compact  Passenger Minivan           19        16         436
# 11215      Compact      Cargo Minivan           20        18         436
# 11374      Midsize              Sedan           24        18         204
# 11376      Midsize              Sedan           24        18         204
# 11378      Midsize              Sedan           24        18         204
# 11419      Midsize  Passenger Minivan           24        18         535
# 11420      Midsize  Passenger Minivan           24        17         535
# 11422      Midsize  Passenger Minivan           22        16         535
# 11423      Midsize  Passenger Minivan           22        16         535
# 11424      Midsize  Passenger Minivan           24        18         535
# 11476      Compact            2dr SUV           26        22         481
# 11477      Compact            2dr SUV           26        22         481
# 11478      Compact            2dr SUV           26        22         481
# 11479      Compact            2dr SUV           26        22         481
# 11480      Compact            2dr SUV           26        22         481
# 11482      Compact            2dr SUV           26        22         481
# 11792      Compact              Coupe           29        22         640
# 11793      Compact              Coupe           26        18         640
# 11794      Compact              Coupe           23        16         640
#
#        MSRP  adjusted_price
# 17     2000           20000
# 19     2000           20000
# 21     2000           20000
# 22     2000           20000
# 23     2000           20000
# 26     2000           20000
# 27     2000           20000
# 28     2000           20000
# 29     2000           20000
# 30     2000           20000
# 31     2000           20000
# 35     2000           20000
# 36     2000           20000
# 37     2000           20000
# 38     2000           20000
# 39     2000           20000
# 40     2000           20000
# 58     2000           20000
# 59     2000           20000
# 60     2000           20000
# 61     2000           20000
# 62     2000           20000
# 63     2000           20000
# 87     2000           20000
# 89     2000           20000
# 90     2000           20000
# 91     2000           20000
# 93     2000           20000
# 95     2073           20730
# 96     3713           37130
# ...     ...             ...
# 11185  2000           20000
# 11189  2000           20000
# 11193  2000           20000
# 11194  2000           20000
# 11195  2000           20000
# 11197  2000           20000
# 11199  2000           20000
# 11200  2000           20000
# 11201  2000           20000
# 11204  2000           20000
# 11205  2000           20000
# 11214  2000           20000
# 11215  2000           20000
# 11374  2000           20000
# 11376  2000           20000
# 11378  2000           20000
# 11419  2000           20000
# 11420  2000           20000
# 11422  2166           21660
# 11423  2110           21100
# 11424  2000           20000
# 11476  2000           20000
# 11477  2000           20000
# 11478  2000           20000
# 11479  2000           20000
# 11480  2000           20000
# 11482  2000           20000
# 11792  2000           20000
# 11793  2000           20000
# 11794  2000           20000
#
# [1249 rows x 16 columns]

# %% [markdown]
# # Replot the new adjusted price.
# * Make the y-axis start at 0 and go up to 100,000

# %%
# Plot new prices
#year_msr = df.groupby('Year')['MSRP']
#year_means = year_msr.mean()# mean of msr by year
#year_means = year_means.reset_index()
#year_means.plot(kind = 'line', x = 'Year', y = 'MSRP', figsize = (13,8))

year_adj_price = df.groupby('Year')['adjusted_price'].mean() 
#year_adj_price.reset_index()
year_adj_price.plot(kind = 'line', x = 'Year', y = 'adjusted_price', figsize = (13,8), ylim = [0,100000])

# %% [markdown]
# # What are top 5 car makers that make the most expensive cars on average.
# * I only want the top 5, make sure your answer is the top 5 and only the top 5. (hint, you can use .head())
# * Use our `adjusted_price` column for this
# * Hint; you're going to have to do a .groupby to answer this.

# %%
# What are the top 5 car makers make the most expensive cars on average. 
highest_avg_prices = df.groupby('Make')['adjusted_price'].mean()
type(highest_avg_prices)
highest_avg_prices.sort_values(ascending = False).head(n=5)
# sort_values used on series
# Out:
# Make
# Bugatti        1.757224e+06
# Maybach        5.462219e+05
# Rolls-Royce    3.511306e+05
# Lamborghini    3.315673e+05
# Bentley        2.471693e+05
# Name: adjusted_price, dtype: float64

# %% [markdown]
# # What are the 5 car makers that have the highest median highway MPG?

# %%
# Which car makers have the highest median highway MPG?
highest_med_prices = df.groupby('Make')['highway MPG'].median()
type(highest_avg_prices)
highest_med_prices.sort_values(ascending = False)
# sort_values used on series
# Out:
# Make
# Alfa Romeo       34
# FIAT             33
# Volkswagen       32
# Scion            32
# Honda            32
# Hyundai          30
# Subaru           29
# Acura            28
# Kia              28
# Mazda            28
# BMW              28
# Audi             28
# Buick            27
# Saab             27
# Mitsubishi       27
# Lotus            26
# Lexus            26
# Cadillac         26
# Volvo            26
# Suzuki           26
# Oldsmobile       26
# Porsche          26
# Pontiac          26
# Nissan           26
# Plymouth         26
# Chrysler         25
# Genesis          25
# Toyota           25
# Infiniti         25
# Lincoln          24
# Mercedes-Benz    23
# Dodge            23
# Chevrolet        23
# GMC              22
# Ford             22
# McLaren          22
# Lamborghini      20
# Maserati         20
# Bentley          19
# Aston Martin     19
# Land Rover       19
# Rolls-Royce      19
# Spyker           18
# HUMMER           18
# Maybach          16
# Ferrari          16
# Bugatti          14
# Name: highway MPG, dtype: int64

# %% [markdown]
# # Using `sns.histplot`, make histogram of the adjusted_price of just these car makers.
# * ['Chevrolet', 'Ford', 'Toyota']
# * Create a temp_df to store the dataframe of just these values.
# * Set the 'hue='Make''.

# %%
# Using `sns.histplot`, make histogram of the adjusted_price of just these car makers.
car_list_df = df[df['Make'].isin(['Chevrolet', 'Ford', 'Toyota'])]
car_list_df.head()
sns.histplot(data = car_list_df, x ='Make', y ='adjusted_price', hue = 'Make')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-9f3dbe1c85ca> in <module>
#       2 car_list_df = df[df['Make'].isin(['Chevrolet', 'Ford', 'Toyota'])]
#       3 car_list_df.head()
# ----> 4 sns.histplot(data = car_list_df, x ='Make', y ='adjusted_price', hue = 'Make')
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %% [markdown]
# # Remake the same histogram, but limit the x-axis from 0 to 100,000

# %%
# Remake the same histogram, but limit the x-axis from 0 to 100,000

# %% [markdown]
# # Plot the relationship between Engine HP and highway MPG

# %%
# Plot the relationship between Engine HP and highway MPG

# %% [markdown]
# # Using `sns.boxplot`, create a boxplot for the 'Engine HP'

# %%
# create a boxplot for the 'Engine HP'

# %% [markdown]
# # Make another boxplot for highway MPG

# %%
# create a boxplot for the 'highway MPG'

# %% [markdown]
# # Remove any  outliers from Engine HP and highway MPG
#
# <img src='https://miro.medium.com/max/1400/1*2c21SkzJMf3frPXPAR_gZA.png' width=500>
#
# * Outliers meaning values that are outside 1.5x the Inter Quartile Range (see image above).
# * For each column (Engine HP and highway MPG):
# * Calculate the 0.25 and 0.75 Quantiles
# * Calculate the Inter Quartile Range (IQR)
# * Create condition mask for the values that are outliers below (in the 'Minimum' range).
# * Create condition mask for the values that are outliers above (in the 'Maximum' range).
# * Filter the dataframe to remove any values that are in the above section _OR_ the below section. (hint; it may be easier to use the inverse selection '~'.
# * Make the same boxplots of Engine HP and Highway MPG as before but with the this dataframe.

# %%
# Remove any  outliers from Engine HP and highway MPG

# %% [markdown]
# # Remake the boxplots for both Engine HP and highway MPG

# %%
# Engine HP boxplot

# %%
# highway MPG boxplot

# %% [markdown]
# # Make a scatter plot of Engine HP vs highway MPG

# %%
# Make a scatter plot of Engine HP vs highway MPG

# %% [markdown]
# # What does this plot tell you about how Engine HP affects highway MPG?

# %%
# What does this plot tell you about how Engine HP affects highway MPG?

print('Your answer here.')
# Out:
# Your answer here.

# %% [markdown]
# # Using a pairplot, display all of the linear relationship.
# * Which variables look like they have the strongest linear relationship (Besides MSRP and adjusted_price).

# %%
# Using a pairplot, display all of the linear relationship.

# %%
# * Which variables look like they have the strongest linear relationship (Besides MSRP and adjusted_price).

# %% [markdown]
# # Find which features actually have the strongest linear relationship using correlations.
# * Make a heatmap plot of all of the correlations in our dataset.
# * Change the figure size of our heatmap plot to be 8x8
# * __Which feature does Engine HP have the strongest relationship with, and why do you think that relationship exists.__

# %%
# * Make a heatmap plot of all of the correlations in our dataset.
# * Change the figure size of our heatmap plot to be 8x8

# %%
# Which feature does Engine HP have the strongest relationship with, and why do you think that relationship exists.

print('Your answer here')
# Out:
# Your answer here

# %% [markdown]
# # [EXTRA CREDIT]
# * In the column names, replace all the spaces with an underscore, and make them all lowercase as well

# %%
# * In the column names, replace all the spaces with an underscore, and make them all lowercase as well
